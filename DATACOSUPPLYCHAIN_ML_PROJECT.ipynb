# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Sarit\Downloads\Data.csv",delimiter=',',encoding = "ISO-8859-1")
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
df.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count      180519.000000       180519.000000       180519.000000
# mean           21.974989          183.107609            0.548291
# std           104.433526          120.043670            0.497664
# min         -4274.979980            7.490000            0.000000
# 25%             7.000000          104.379997            0.000000
# ...

# %%
df.boxplot(column=['Product Price'])
# Out:
# <AxesSubplot:>

# %%
df.isnull()
# Out:
#          Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0       False                     False                          False
# 1       False                     False                          False
# 2       False                     False                          False
# 3       False                     False                          False
# 4       False                     False                          False
# ...       ...                       ...                            ...
# 180514  False                     False                          False
# 180515  False                     False                          False
# 180516  False                     False                          False
# 180517  False                     False                          False
# 180518  False                     False                          False
#
#         Benefit per order  Sales per customer  Delivery Status  \
# ...

# %%
df.isnull().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# ...

# %%
df.drop('Order Zipcode', axis = 'columns')
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df.count()
# Out:
# Type                             180519
# Days for shipping (real)         180519
# Days for shipment (scheduled)    180519
# Benefit per order                180519
# Sales per customer               180519
# Delivery Status                  180519
# Late_delivery_risk               180519
# Category Id                      180519
# Category Name                    180519
# Customer City                    180519
# Customer Country                 180519
# Customer Email                   180519
# Customer Fname                   180519
# Customer Id                      180519
# Customer Lname                   180511
# Customer Password                180519
# Customer Segment                 180519
# Customer State                   180519
# Customer Street                  180519
# Customer Zipcode                 180516
# Department Id                    180519
# Department Name                  180519
# Latitude                         180519
# ...

# %%
col_max = df.max(axis=0)
col_max
# Out:
# Type                                                                      TRANSFER
# Days for shipping (real)                                                         6
# Days for shipment (scheduled)                                                    4
# Benefit per order                                                            911.8
# Sales per customer                                                         1939.99
# Delivery Status                                                   Shipping on time
# Late_delivery_risk                                                               1
# Category Id                                                                     76
# Category Name                                                   Women's Golf Clubs
# Customer City                                                           Zanesville
# Customer Country                                                       Puerto Rico
# ...

# %%
df['Order City'].value_counts()
# Out:
# Santo Domingo      2211
# New York City      2202
# Los Angeles        1845
# Tegucigalpa        1783
# Managua            1682
#                    ...
# Focsani               1
# Annecy-le-Vieux       1
# Warner Robins         1
# Missoula              1
# Jincheng              1
# Name: Order City, Length: 3597, dtype: int64

# %%
df['Order Status'].value_counts()
# Out:
# COMPLETE           59491
# PENDING_PAYMENT    39832
# PROCESSING         21902
# PENDING            20227
# CLOSED             19616
# ON_HOLD             9804
# SUSPECTED_FRAUD     4062
# CANCELED            3692
# PAYMENT_REVIEW      1893
# Name: Order Status, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
grp = df.groupby('Order City')
grp.count()
# Out:
#                        Type  Days for shipping (real)  \
# Order City
# Aachen                   63                        63
# Aalen                     3                         3
# Aalst                    23                        23
# Aba                      36                        36
# Abadan                   33                        33
# ...                     ...                       ...
# Zwolle                    9                         9
# eMbalenhle                7                         7
# Águas Lindas de Goiás    13                        13
# Çanakkale                 6                         6
# Ústí nad Labem           14                        14
#
#                        Days for shipment (scheduled)  Benefit per order  \
# Order City
# Aachen                                            63                 63
# Aalen                                              3                  3
# ...

# %%
mg = df[df['Order Country']=='India']
mg
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 13         DEBIT                         2                              1
# 14      TRANSFER                         2                              1
# 15         DEBIT                         2                              1
# ...          ...                       ...                            ...
# 180488   PAYMENT                         2                              4
# 180490  TRANSFER                         4                              4
# 180493     DEBIT                         2                              4
# 180494     DEBIT                         2                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
list(set(mg['Order City']))
# Out:
# ['Tirupati',
#  'Amritsar',
#  'Satna',
#  'Jabalpur',
#  'Jamshedpur',
#  'Parbhani',
#  'Sonipat',
#  'Bareilly',
#  'Etawah',
#  'Bhilai',
#  'Jhansi',
#  'Kota',
#  'Jalna',
#  'Amravati',
#  'Puducherry',
#  'Madurai',
#  'Udaipur',
#  'Kanpur',
#  'Korba',
#  'Kochi',
#  'Mumbai',
#  'Faridabad',
#  'Imphal',
#  'Baranagar',
#  'Dhule',
#  'Ambattur',
#  'Bokaro',
#  'Varanasi',
#  'Guntur',
#  'Mangalore',
#  'Kozhikode',
#  'Jamnagar',
#  'Kulti',
#  'Shahjahanpur',
#  'Srinagar',
#  'Surat',
#  'Indore',
#  'Tirunelveli',
#  'Kakinada',
#  'Latur',
#  'Firozabad',
#  'Bikaner',
#  'Ujjain',
#  'Lucknow',
#  'Meerut',
#  'Hubli',
#  'Fatehpur',
#  'Tiruppur',
#  'Nasik',
#  'Mysore',
#  'Bhatpara',
#  'Ichalkaranji',
#  'Bellary',
#  'Solapur',
#  'Karnal',
#  'Bhilwara',
#  'Ulhasnagar',
#  'Malegaon',
#  'Jaipur',
#  'New Delhi',
#  'Delhi',
#  'Thiruvananthapuram',
#  'Pimpri',
#  'Saharanpur',
#  'Vijayawada',
#  'Salem',
#  'Tumkur',
#  'Mirzapur',
#  'Akola',
# ...

# %%
mg['Order City'].value_counts()
# Out:
# Delhi           181
# Mumbai          167
# Pune            162
# Bangalore       142
# Chennai         133
#                ...
# Kakinada          3
# Shimoga           3
# Barasat           3
# Shahjahanpur      1
# New Delhi         1
# Name: Order City, Length: 146, dtype: int64

# %%
mg['Order Status'].value_counts()
# Out:
# COMPLETE           1568
# PENDING_PAYMENT    1068
# PROCESSING          573
# CLOSED              540
# PENDING             537
# ON_HOLD             276
# SUSPECTED_FRAUD     116
# CANCELED             78
# PAYMENT_REVIEW       27
# Name: Order Status, dtype: int64

# %%
mg2 = mg[mg['Order Status']=='PENDING']
mg2
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 1       TRANSFER                         5                              4
# 21      TRANSFER                         5                              4
# 45      TRANSFER                         6                              4
# 46      TRANSFER                         5                              2
# 382     TRANSFER                         3                              4
# ...          ...                       ...                            ...
# 180142  TRANSFER                         4                              4
# 180164  TRANSFER                         2                              1
# 180248  TRANSFER                         5                              2
# 180331  TRANSFER                         3                              4
# 180405  TRANSFER                         2                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
mg2['Order Status'].value_counts()
# Out:
# PENDING    537
# Name: Order Status, dtype: int64

# %%
list(set(mg2['Order City']))
# Out:
# ['Satna',
#  'Amritsar',
#  'Jabalpur',
#  'Parbhani',
#  'Jhansi',
#  'Kota',
#  'Amravati',
#  'Puducherry',
#  'Madurai',
#  'Kanpur',
#  'Korba',
#  'Mumbai',
#  'Faridabad',
#  'Imphal',
#  'Bokaro',
#  'Mangalore',
#  'Jamnagar',
#  'Kulti',
#  'Srinagar',
#  'Surat',
#  'Tirunelveli',
#  'Bikaner',
#  'Lucknow',
#  'Ujjain',
#  'Meerut',
#  'Hubli',
#  'Fatehpur',
#  'Nasik',
#  'Tiruppur',
#  'Mysore',
#  'Ichalkaranji',
#  'Bellary',
#  'Solapur',
#  'Ulhasnagar',
#  'Malegaon',
#  'Jaipur',
#  'Delhi',
#  'Thiruvananthapuram',
#  'Saharanpur',
#  'Pimpri',
#  'Salem',
#  'Gulbarga',
#  'Coimbatore',
#  'Durg',
#  'Ganganagar',
#  'Ajmer',
#  'Hyderabad',
#  'Guwahati',
#  'Shimoga',
#  'Agra',
#  'Muzaffarpur',
#  'Jammu',
#  'Bhavnagar',
#  'Bilaspur',
#  'Durgapur',
#  'Chandigarh',
#  'Patiala',
#  'Vadodara',
#  'Brahmapur',
#  'Aurangabad',
#  'Chennai',
#  'Rajkot',
#  'Bihar Sharif',
#  'Bhopal',
#  'Hisar',
#  'Bangalore',
#  'Anantapur',
#  'Bhiwandi',
# ...

# %%
mg2['Order City'].value_counts()
# Out:
# Kanpur          25
# Pune            24
# Bangalore       24
# Lucknow         21
# Delhi           18
#                 ..
# Ichalkaranji     1
# Bilaspur         1
# Aurangabad       1
# Patiala          1
# Jamnagar         1
# Name: Order City, Length: 91, dtype: int64

# %%
#Q2-COUNTRY WITH MOST SUSPECTED FRAUD

# %%
mg3 = df[df['Order Status']=='SUSPECTED_FRAUD']
mg3
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 10      TRANSFER                         6                              2
# 24      TRANSFER                         2                              2
# 183     TRANSFER                         5                              4
# 184     TRANSFER                         5                              4
# 185     TRANSFER                         6                              4
# ...          ...                       ...                            ...
# 180274  TRANSFER                         5                              2
# 180309  TRANSFER                         2                              1
# 180352  TRANSFER                         4                              4
# 180406  TRANSFER                         6                              4
# 180490  TRANSFER                         4                              4
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
mg3['Order Status'].value_counts()
# Out:
# SUSPECTED_FRAUD    4062
# Name: Order Status, dtype: int64

# %%
mg3['Order Country'].value_counts()
# Out:
# Estados Unidos     573
# Francia            362
# México             317
# Alemania           227
# Australia          197
#                   ...
# Uzbekistán           1
# Costa de Marfil      1
# Benín                1
# Jamaica              1
# Bangladés            1
# Name: Order Country, Length: 102, dtype: int64

# %%
#Q3-PRODUCTS WITH MINIMUM DISCOUNT

# %%
df['Order Item Discount'].value_counts()
# Out:
# 0.000000     10028
# 6.000000      4589
# 12.000000     4067
# 4.000000      3647
# 8.000000      3626
#              ...
# 57.599998        1
# 40.799999        1
# 54.400002        1
# 61.740002        1
# 80.739998        1
# Name: Order Item Discount, Length: 1017, dtype: int64

# %%
dis_max = df.max(axis=0)
dis_max
# Out:
# Type                                                                      TRANSFER
# Days for shipping (real)                                                         6
# Days for shipment (scheduled)                                                    4
# Benefit per order                                                            911.8
# Sales per customer                                                         1939.99
# Delivery Status                                                   Shipping on time
# Late_delivery_risk                                                               1
# Category Id                                                                     76
# Category Name                                                   Women's Golf Clubs
# Customer City                                                           Zanesville
# Customer Country                                                       Puerto Rico
# ...

# %%
df['Order Item Discount'].max()
# Out:
# 500.0

# %%
df['Product Name'].value_counts()
# Out:
# Perfect Fitness Perfect Rip Deck                 24515
# Nike Men's CJ Elite 2 TD Football Cleat          22246
# Nike Men's Dri-FIT Victory Golf Polo             21035
# O'Brien Men's Neoprene Life Vest                 19298
# Field & Stream Sportsman 16 Gun Fire Safe        17325
#                                                  ...
# Stiga Master Series ST3100 Competition Indoor       27
# SOLE E35 Elliptical                                 15
# Bushnell Pro X7 Jolt Slope Rangefinder              11
# Bowflex SelectTech 1090 Dumbbells                   10
# SOLE E25 Elliptical                                 10
# Name: Product Name, Length: 118, dtype: int64

# %%
#Q5-NUMBER OF SUCCESSFULL ORDERS WITH SHIPPING DAYS > DAYS OF SHIPMENT

# %%
mg5 = df[df['Order Status']=='COMPLETE']
mg5
# Out:
#          Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0       DEBIT                         3                              4
# 3       DEBIT                         3                              4
# 6       DEBIT                         2                              1
# 13      DEBIT                         2                              1
# 15      DEBIT                         2                              1
# ...       ...                       ...                            ...
# 180500  DEBIT                         3                              4
# 180505  DEBIT                         2                              4
# 180508  DEBIT                         4                              2
# 180512  DEBIT                         6                              4
# 180515  DEBIT                         3                              2
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
mg5['boolean'] = mg5['Days for shipping (real)'] > mg5['Days for shipment (scheduled)']
mg5
# Out:
# <ipython-input-95-fd9ae6d2d205>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mg5['boolean'] = mg5['Days for shipping (real)'] > mg5['Days for shipment (scheduled)']
#          Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0       DEBIT                         3                              4
# 3       DEBIT                         3                              4
# 6       DEBIT                         2                              1
# 13      DEBIT                         2                              1
# 15      DEBIT                         2                              1
# ...       ...                       ...                            ...
# ...

# %%
mg5['boolean'].value_counts()
# Out:
# True     34199
# False    25292
# Name: boolean, dtype: int64
